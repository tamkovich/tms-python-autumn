# %% [markdown]
# # Объектно-ориентированное программирование (ООП) (Часть 1)

# %% [markdown]
# ### Синтаксис
#
# <code>class ИмяКласса:
#    атрибуты_класса
#    методы_класса
# </code>

# %% [markdown]
# ###  Задание 11.01
#
# Создать пустой класс Dog

# %%
class Dog:
    pass

# %% [markdown]
# ###  Создание объекта

# %%
# Dog - имя класса
dog = Dog() #  dog - Объект(экземпляр) класса Dog

# %%
print(dog)
# Out:
# <__main__.Dog object at 0x7fb987311640>

# %% [markdown]
# ###  Задание 11.02
#
# Создать два объекта класса Dog. Вывести их на экран

# %%
dog1 = Dog()
dog2 = Dog()
print(dog1)
print(dog2)
# Out:
# <__main__.Dog object at 0x7ff14756ff10>
# <__main__.Dog object at 0x7ff14756fed0>

# %% [markdown]
# ###  Методы класса

# %%
class Dog:
    def bark(self):
        print('Woof Woof!')

# %% [markdown]
# **self** - обязательный атрибут метода. Позволяет обращаться к атрибутам и методам объекта

# %%
dog_1 = Dog()
dog_1.bark()  # Обращение к методам происходит через точку
# Out:
# Woof Woof!

# %% [markdown]
# _Какие еще бывают методы, к которым можно обратиться через '.' ?_

# %% [markdown]
# ###  Задание 11.03
#
# Добавить два метода в класс Dog: jump и run. Методы выводят на экран Jump! и Run! соответственно.

# %%
class Dog:
    def bark(self):
        print('Woof Woof!')

# %%
dog = Dog()
dog.bark()
dog.jump()
dog.run()
# Out:
# Woof Woof!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5d313ee3aaa3> in <module>
#       1 dog = Dog()
#       2 dog.bark()
# ----> 3 dog.jump()
#       4 dog.run()
#
# AttributeError: 'Dog' object has no attribute 'jump'

# %%
dog2 = Dog()
result = dog2.bark()
# Out:
# Woof Woof!

# %%
print(result)
# Out:
# None

# %% [markdown]
# ### Конструктор
#
# - Конструктор - метод, который вызывается, когда создается объект.
# - Конструктор инициализирует атрибуты объекта

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):
        print('Woof Woof!')

# %%
dog_1 = Dog('Bob')
print(dog_1.name)
print(dog_1.bark())
# Out:
# Bob
# Woof Woof!
# None

# %%
dog_2 = Dog('Rex')
print(dog_2.name)
# Out:
# Rex

# %% [markdown]
# ###  Задание 11.04
#
# Создать класс Dog. Класс имеет четыре атрибута: height, weight, name, age. Класс имеет три метода: jump, run, bark. Каждый метод выводит сообщение на экран. Создать объект класса Dog, вызвать все методы объекта и вывести на экран все его атрибуты.

# %%
class Dog:
    
    def __init__(self, height, weight, name, age):
        pass

    def bark(self):
        pass
    
    def jump(self):
        pass
    
    def run(self):
        pass


dog = Dog(20, 10, "Bob", 7)
dog.bark()
dog.jump()
dog.run()

print(dog.height)
print(dog.weight)
print("Имя: ", dog.name)
print(dog.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-541c1862ed68> in <module>
#      19 dog.run()
#      20
# ---> 21 print(dog.height)
#      22 print(dog.weight)
#      23 print("Имя: ", dog.name)
#
# AttributeError: 'Dog' object has no attribute 'height'

# %% [markdown]
# ###  Изменение атрибутов

# %%
class Dog: 
    ...
    def change_height(self, height): 
        self.height = height  # задали новое значение

# %%
dog_1 = Dog(20, 10, "Bob", 7)
print(dog_1.height)

dog_1.change_height(15)
print(dog_1.height)

# %%
# Вариант второй (напрямую)
dog_1.height = 77
print(dog_1.height)

# %% [markdown]
# ###  Задание 11.05
#
# Добавить в класс Dog метод change_name. Метод принимает на вход новое имя и меняет атрибут имени у объекта. Создать один объект класса. Вывести имя. Вызвать метод change_name. Вывести имя.

# %%
class Dog:
    def __init__(self, height, weight, name, age):
        self.height = height
        self.weight = weight
        self.name = name
        self.age = age
        
    ...
        
    def change_name(self, name):
        # задали новое имя
        pass

# %%
dog_1 = Dog(20, 10, "Bob", 7)
print(dog_1.name)

dog_1.change_name("Rex")
print(dog_1.name)
# Out:
# Bob
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-30b5fd0193b0> in <module>
#       2 print(dog_1.name)
#       3
# ----> 4 dog_1.__change_name("Rex")
#       5 print(dog_1.name)
#
# AttributeError: 'Dog' object has no attribute '__change_name'

# %% [markdown]
# ###  Модификаторы доступа

# %%
class Dog:
    def __init__(self, name, age, weight):
        self.__name = name      # private 
        self._age = age         # protected 
        self.weight = weight    # public

# %%
dog = Dog('Bob', 8, 2.4)

# %%
print(dog.__name) # ERROR
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-2a56c4d37255> in <module>
# ----> 1 print(dog.__name) # ERROR
#
# AttributeError: 'Dog' object has no attribute '__name'

# %%
print(dog._Dog__name)
# Out:
# Bob

# %%
print(dog._age)
# Out:
# 8

# %%
print(dog.weight)
# Out:
# 2.4

# %% [markdown]
# ###  Задание 11.06
#
# Добавить в метод инициализации новый приватный атрибут - name. Создать метод get_name() который возвращает значение атрибута master.

# %%
class Dog:
    def __init__(self, name):
        self.__name = name
    
    def get_name(self):
        return self.__name

# %%
dog = Dog('Charlie')
print(dog.get_name())
# Out:
# Charlie

# %% [markdown]
# ### getter, setter

# %%
class Dog: 
    def __init__(self, name):
        self.__name = name
    
    def get_name(self):
        return self.__name
    
    def set_name(self, name): 
        self.__name = name

# %%
dog = Dog('Alex')
print(dog.get_name())

dog.set_name('Pavel')
print(dog.get_name())
# Out:
# Alex
# Pavel

# %% [markdown]
# ###  Задание 11.07
#
# Добавить новый приватный атрибут адрес(по-умолчанию равен ‘Minsk’). Добавить getter и setter для адреса.

# %%
class Dog:
    def __init__(self, city="Minsk"):
        self.__city = city
    
    # getter city
    def get_city()
    
    # setter city
    def set_city()

dog = Dog()
print(dog.get_city())
dog.set_city("Moscow")
print(dog.get_city())
# Out:
# Minsk
# Moscow

# %% [markdown]
# ### getter, setter через декораторы
#
# - Декоратор @property позволяет обращаться к методам без использования скобок
# - Декоратор @имя_метода.setter позволяет передавать аргумент в функцию через знак присваивания =

# %%
class Dog:
    def __init__(self, name):
        self.__name = name 

    @property
    def name(self): 
        return self.__name

    @name.setter
    def name(self, name):
        if len(name) < 5: 
            self.__name = name

# %%
dog = Dog('Alex') 
dog.name = 'Max'
print(dog.name)
# Out:
# Moe

# %% [markdown]
# ###  Задание 11.08
#
# Сделать все атрибуты класса Dog приватными. Сделать для каждого атрибута getter и setter используя декораторы. Все change методы удалить

# %%
class Dog:
    def __init__(self, name, height, weight, age):
        self.__height = height
        self.__weight = weight
        self.__name = name
        self.__age = age
        # MAKE ALL PRIVATE

    @property
    def name(self):
        return self.__name
    
    @name.setter
    def name(self, name):
        self.__name = name

# %%
dog = Dog('Bob', 8, 2.4, 10)
dog.name
# Out:
# 'Bob'

# %%
type(dog)
# Out:
# __main__.Dog

# %%
dog.name = "Jack"

# %%
dog.name
# Out:
# 'Jack'

# %% [markdown]
# ### Класс как тип данных

# %%
class Point:
    def __init__(self, x, y):
        self.x = x 
        self.y = y


class Square:
    def __init__(self, point_a, point_b):
        self.point_a = point_a 
        self.point_b = point_b

# %%
first_point = Point(1, 1)
second_point = Point(4, 4)

# %%
square = Square(first_point, second_point)

# %%
first_point.x
# Out:
# 1

# %%
square.point_a, square.point_b
# Out:
# (<__main__.Point at 0x7ff1492ee7d0>, <__main__.Point at 0x7ff1492ee250>)

# %%
square.point_a.x, square.point_a.y
# Out:
# (1, 1)

# %% [markdown]
# ###  Задание 11.09 (ДЗ)
#
# Создать три класса: Dog, Cat, Parrot. Атрибуты каждого класса: name, age, master. Каждый класс содержит конструктор и методы: run, jump, birthday(увеличивает age на 1), sleep. Класс Parrot имеет дополнительный метод fly. Cat - meow, Dog - bark.

# %%
class Dog:
    # конструктор __init__
    
    # Run!
    
    # Jump!
    
    def birthday():
        # Увеличить self.age
        
    # Sleep!

# %%
class Cat:
    pass

# %%
class Parrot:
    pass

# %% [markdown]
# ### Наследование
#
# Дочерний класс наследуют все методы родитльского класса.

# %%
class Wolf:
    def bark(self):
        print('WOOooOOOoooo')
        

class Dog(Wolf):
    pass

# %%
dog = Dog()
dog.bark()
# Out:
# WOOooOOOoooo

# %% [markdown]
# ###  Задание 11.10
#
# Создать родительский класс Pet, содержащий все общие методы классов Dog, Cat, Parrot. Унаследовать Dog, Cat, Parrot от класса Pet. Удалить в дочерних классах те методы, которые имеются у родительского класса. Создать объект каждого класса и вызвать все его методы.

# %%
class Pet:
    def run(self):
        print("Run!")


class Dog(Pet):
    def run(self):
        print("Runnnnnnnn!")

        
class Cat(Pet):
    pass


class Parrot(Pet):
    pass

# %%
pet = Pet()
pet.run()
# Out:
# Run!

# %%
dog = Dog()
dog.run()
# Out:
# Runnnnnnnn!

# %%
cat = Cat()
cat.run()
# Out:
# Run!

# %% [markdown]
# ### Переопределение методов

# %%
class Wolf:
    def bark(self):
        print('WOOooOOOoooo')


class Dog(Wolf):
    def bark(self):
        print("Гав Гав!")

# %%
dog = Dog()
dog.bark()
# Out:
# Гав Гав!

# %%
wolf = Dog()
wolf.bark()
# Out:
# Гав Гав!

# %% [markdown]
# ### Переопределение аттрибутов

# %%
class Car:
    def __init__(self, count):
        self.count = count

# %%
car = Car(4)
print(car.count)
# Out:
# 4

# %%
class BMW(Car):
    def __init__(self, count, is_swag):
        self.count = count
        self.is_swag = is_swag
        
    def off(self):
        print("Я ВСЕ :(")

# %%
bmw = BMW(4, True)
print(bmw.count)
# Out:
# 4

# %%
bmw.off()
# Out:
# Я ВСЕ :(

# %%
bmw.is_swag
# Out:
# True

# %%
car.off()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-4360b5c7cd6e> in <module>
# ----> 1 car.off()
#
# AttributeError: 'Car' object has no attribute 'off'

# %%
car.is_swag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-c9db9201393b> in <module>
# ----> 1 car.is_swag
#
# AttributeError: 'Car' object has no attribute 'is_swag'

# %% [markdown]
# ###  Задание 11.11 (ДЗ)
#
# Добавить два новых атрибута в родительский класс: weight и height.
#
# Добавить методы change_weight, change_height принимающий один параметр и прибавляющий его к соответствующему аргументу. В случае если параметр не был передан, увеличивать на 0.2.
#
# Изменить метод fly класса Parrot. Если вес больше 0.1 выводить сообщение This parrot cannot fly.

# %%
class Pet:
    def __init__(self, weight, height):
        self.weight = weight
        self.height = height

    def change_weight(self, weight=0.2):
        self.weight += weight

    def change_height(self, height):
        pass
    

class Parrot(Pet):
    def fly(self):
        """
        Если вес больше 0.1 выводить сообщение 
        This parrot cannot fly.
        """
        if self.weight > 0.1:
            print('This parrot cannot fly')
        else:
            print('Fly Fly Fly!')


class Dog:
    pass


class Cat:
    pass

# %%
parrot = Parrot(1, 4)
print(parrot.weight)  # 1
# Out:
# 1

# %%
parrot.change_weight(2.5)
print(parrot.weight)  # 3.5
# Out:
# 3.5

# %%
parrot.change_weight()
print(parrot.weight)  # 3.7
# Out:
# 3.7

# %%
parrot.fly() # This parrot cannot fly.
# Out:
# This parrot cannot fly

# %%
parrot.change_weight(-3.65)
parrot.fly()  # Fly!
# Out:
# Fly Fly Fly!

# %% [markdown]
# # Задание ДЗ 1
# Создать пять классов описывающие реальные объекты. Каждый класс должен содержать минимум три приватных атрибута, конструктор, геттеры и сеттеры для каждого атрибута, два метода.

# %%
class Car:
    pass

# %%
class BMW(Car):
    pass

# %%
class Opel(Car):
    pass

# %%
class Person:
    pass

# %%
class Driver(Person):
    pass

# %% [markdown]
# # Задание ДЗ 2
# Создать класс Car. Атрибуты: марка, модель, год выпуска, скорость(по умолчанию 0). Методы: увеличить скорости(скорость + 5), уменьшение скорости(скорость - 5), стоп(сброс скорости на 0), отображение скорости, разворот(изменение знака скорости). Все атрибуты приватные.
