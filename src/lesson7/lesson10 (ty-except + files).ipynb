# %% [markdown]
# # Исключения в python. Конструкция try - except для обработки исключений

# %% [markdown]
# ## Рубрика "Потом разберём"

# %% [markdown]
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html

# %%
100 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-e9e866a10e2a> in <module>
# ----> 1 100 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# - Traceback (most recent call last) - было поймано исключение
# - File + line
# - Выражение, в котором произошла ошибка (100 / 0).
# - Название исключения (ZeroDivisionError) и краткое описание исключения (division by zero).

# %%
2 + '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ec91ee6d378c> in <module>
# ----> 1 2 + '1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
int('13q')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-87d81536ff6c> in <module>
# ----> 1 int('13q')
#
# ValueError: invalid literal for int() with base 10: '13q'

# %% [markdown]
# ## Использование try-except

# %%
try:
    k = 1 / 10
    2 + '1'
    print('Результат операции: ', k)
except:
    print('Неверное число, попробуйте поделить на другое')
# Out:
# Неверное число, попробуйте поделить на другое

# %%
try:
    k = 1 / 10
except ZeroDivisionError:
    print('Неверное число, попробуйте поделить на другое')
    k = 0

print(k)
# Out:
# 0.1

# %% [markdown]
# ## Вызов ошибки

# %%
raise ZeroDivisionError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-c62fc6984c64> in <module>
# ----> 1 raise ZeroDivisionError
#
# ZeroDivisionError:

# %%
raise TypeError

a = 1 + 2
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-37cae06b7100> in <module>
# ----> 1 raise TypeError
#       2
#       3 a = 1 + 2
#       4 print(a)
#
# TypeError:

# %%
try:
    raise TypeError
except TypeError:
    print('Что-то пошло не так')

a = 1 + 2
print(a)
# Out:
# Что-то пошло не так
# 3

# %% [markdown]
# ## Печать деталей ошибки

# %%
res = []

try:
    k = 1 / 0
except ZeroDivisionError as e:
    k = 0
    print(e.args)
    
print(k)
# Out:
# ('division by zero',)
# 0

# %%
res = []

try:
    k = 1 / 0
except ZeroDivisionError as e:
    k = 0
    res.append(e)

print(res)
raise res[0]
# Out:
# [ZeroDivisionError('division by zero')]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-11-0f3a1e29d31b> in <module>
#       8
#       9 print(res)
# ---> 10 raise res[0]
#
# <ipython-input-11-0f3a1e29d31b> in <module>
#       2
#       3 try:
# ----> 4     k = 1 / 0
#       5 except ZeroDivisionError as e:
#       6     k = 0
#
# ZeroDivisionError: division by zero

# %%
res = []

try:
    int('asdas')
except Exception as e:
    k = 0
    print(e.args)
    
print(k)
# Out:
# ("invalid literal for int() with base 10: 'asdas'",)
# 0

# %% [markdown]
# ## Finaly

# %%
try:
    k = 10 / 0
except ZeroDivisionError as e:
    k = 0
finally:
    print('Функция отработала (возможно с ошибкой хз)')
    print(k)
# Out:
# Функция отработала (возможно с ошибкой хз)
# 0

# %%
try:
    k = 10 / 2
except ZeroDivisionError as e:
    k = 0
finally:
    print('Функция отработала (возможно с ошибкой хз)')
    print(k)
# Out:
# Функция отработала (возможно с ошибкой хз)
# 5.0

# %%
k = 1111
try:
    k = int('13q')
except ZeroDivisionError as e:
    k = 0
finally:
    print('Функция отработала (возможно с ошибкой хз)')
    print(k)
# Out:
# Функция отработала (возможно с ошибкой хз)
# 1111
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-72487e9a9bd1> in <module>
#       1 k = 1111
#       2 try:
# ----> 3     k = int('13q')
#       4 except ZeroDivisionError as e:
#       5     k = 0
#
# ValueError: invalid literal for int() with base 10: '13q'

# %% [markdown]
# # Файлы. Работа с файлами.

# %% [markdown]
# https://pythonworld.ru/tipy-dannyx-v-python/fajly-rabota-s-fajlami.html

# %%
f = open('test.txt', 'r')

# %% [markdown]
# ## Чтение из файла

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='UTF-8'>

# %%
print(f.read())
# Out:
# Hello Worldssss

# %% [markdown]
# ## Запись в файл

# %%
f = open('test.txt', 'w')

# %%
f.write('Bla bla ')
# Out:
# 8

# %%
f.close()

# %% [markdown]
# ## Дополнить файл

# %%
f = open('test.txt', 'a')

# %%
f.write('Bla bla ')
# Out:
# 8

# %%
f.close()

# %%
f = open('test.txt', 'a')

# %%
for index in ["dog", "cat", "cow"]:
    f.write(index + '\n')

# %%
f.close()

# %% [markdown]
# ## Чтение построчное

# %%
f = open('test.txt', 'r')

# %%
f.read()
# Out:
# 'dog\ncat\ncow\n'

# %%
f.close()

# %%
f = open('test.txt', 'r')

# %%
f.readlines()
# Out:
# ['dog\n', 'cat\n', 'cow\n']

# %%
for line in f.readlines():
    print(line)
# Out:
# dog
#
# cat
#
# cow

# %%
f.close()

# %%
f = open('test.txt', 'r')

# %%
print(f.readline())
print(f.readline())
# Out:
# dog
#
# cat

# %%
f.close()

# %% [markdown]
# ## with open('test.txt', 'r') as f:
#
# https://pythonworld.ru/osnovy/with-as-menedzhery-konteksta.html

# %%
# f = open('test.txt', 'r')
# f.close()

with open('test.txt', 'r') as f:  
    print(f.read())
# Out:
# dog
# cat
# cow

# %% [markdown]
# ## JSON

# %%
import json

# %%
with open('file2.json', 'r') as f: 
    content = f.read()
    print(content)
    print(type(content))
    print(content['some_bool'])
# Out:
# {
#     "some_str": "string",
#     "some_array": [1,2,3,4],
#     "some_bool": true,
#     "some_null": null,
#     "some_matrix": [[1,2],[3,4]]
# }
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d2bdaf929558> in <module>
#       3     print(content)
#       4     print(type(content))
# ----> 5     print(content['some_bool'])
#
# TypeError: string indices must be integers

# %%
with open('file2.json', 'r') as f:
    json_content = f.read()  # читает данные из файла 
    data = json.loads(json_content)  # преобразует json-строку в python словарь
    print(data)
    print(type(data))
    print(data['some_bool'])
# Out:
# {'some_str': 'string', 'some_array': [1, 2, 3, 4], 'some_bool': True, 'some_null': None, 'some_matrix': [[1, 2], [3, 4]]}
# <class 'dict'>
# True

# %% [markdown]
# # Запись и создание JSON

# %%
with open('file3.json', 'w') as f:
    json_content = {
        "name": "Zeka",
        "country": "Brazil",
    }
    data = json.dumps(json_content)  # преобразует python-словарь в json-строку
    print(data)
    print(type(data))
    f.write(data)
# Out:
# {"name": "Zeka", "country": "Brazil"}
# <class 'str'>

# %% [markdown]
# ## CSV

# %%
import csv

# %% [markdown]
# ## Чтение из файла

# %%
with open('excel.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile) 
    for row in csvreader:
        print(row)
# Out:
# ['name', 'lastname', 'date']
# ['игорь', 'иванов', '2000']
# ['дима', 'петров', '1990']

# %%
"date,age,name".split(',')
# Out:
# ['date', 'age', 'name']

# %% [markdown]
# ## Запись в csv файл

# %%
fields = ['firstname', 'lastname', 'group'] 
filename = "students_info.csv" 
with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile) 
    csvwriter.writerow(fields)  # запишет одну строку

# %%
rows = [
    ['Ivan', 'Ivanov', 'Z-23'],
    ['Petr', 'Petrov', 'Z-23'], 
]
filename = "students_info.csv" 
with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile) 
    csvwriter.writerows(rows)  # запишет несколько строк

# %% [markdown]
# ## Запись в csv файл через ; (свой символ)

# %%
rows = [
    ['Ivan', 'Ivanov', 'Z-23'],
    ['Petr', 'Petrov', 'Z-23'], 
]
filename = "students_info.csv" 
with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=';') 
    csvwriter.writerows(rows)  # запишет несколько строк

# %% [markdown]
# # Задание 10.01
#
# Имеется текстовый файл. Напечатать:
# - a) его первую строку;
# - b) его пятую строку;
# - c) его первые 5 строк;
# - d) его строки с s1-й по s2-ю;
# - e) весь файл.

# %%
#a
with open('task1.txt', 'r') as f:
    print(f.readline())
# Out:
# Dear Zeka,

# %%
#b
with open('task1.txt', 'r') as f:
    print(f.readlines()[4])
# Out:
# And nice

# %%
#c
with open('task1.txt', 'r') as f:
    print(f.readlines()[:4])
# Out:
# ['Dear Zeka,\n', 'I am from USA\n', 'I like food\n', 'You are good\n']

# %%
#d
s1 = 3
s2 = 7
with open('task1.txt', 'r') as f:
    print(f.readlines()[s1:s2])
# Out:
# ['You are good\n', 'And nice\n', 'How old are you?\n', 'I like football\n']

# %%
#e
with open('task1.txt', 'r') as f:
    print(f.read())
# Out:
# Dear Zeka,
# I am from USA
# I like food
# You are good
# And nice
# How old are you?
# I like football
# Do you like it?
# Cool!!!!!
# Superrrrrrrrr:)
# Wow
# Music bad
